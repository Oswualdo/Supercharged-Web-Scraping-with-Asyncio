# %%
# !pip install requests-html selenium arsenic pandas

# %% [markdown]
# ##  Sync vs Async
#
# The Chess Game Analogy
#
# Consecutive vs Concurrent

# %%
# %%time

import time

iteration_times = [1, 3, 2, 4]


def sleeper(seconds, i=-1):
    if i != -1:
        print(f"{i}\t{seconds}s")
    time.sleep(seconds)


def run():
    for i, second in enumerate(iteration_times):
        sleeper(second, i=i)
    
run()
# Out:
# 0	1s
# 1	3s
# 2	2s
# 3	4s
# CPU times: user 8.99 ms, sys: 736 µs, total: 9.72 ms
# Wall time: 10 s

# %%
start = time.time()
iteration_times = [1, 3, 2, 1]
import asyncio

async def a_sleeper(seconds, i=-1):
    if i != -1:
        print(f"{i}\t{seconds}s")
    await asyncio.sleep(seconds) # coroutine
    
    ellap = time.time() - start
    print(f"{i} done {ellap}")
    return "abc"

async def a_run():
    results = []
    for i, second in enumerate(iteration_times):
        results.append(
            asyncio.create_task(a_sleeper(second, i=i))
        )
    return results
    
results = await a_run()
print(results)
end = time.time() - start

print(end)
# Out:
# [<Task pending name='Task-5' coro=<a_sleeper() running at /tmp/ipykernel_35607/2677998759.py:5>>, <Task pending name='Task-6' coro=<a_sleeper() running at /tmp/ipykernel_35607/2677998759.py:5>>, <Task pending name='Task-7' coro=<a_sleeper() running at /tmp/ipykernel_35607/2677998759.py:5>>, <Task pending name='Task-8' coro=<a_sleeper() running at /tmp/ipykernel_35607/2677998759.py:5>>]
# 0.0005695819854736328
# 0	1s
# 1	3s
# 2	2s
# 3	1s
# 0 done 1.0030004978179932
# 3 done 1.00321626663208
# 2 done 2.0025668144226074
# 1 done 3.0030665397644043

# %% [markdown]
# ## Blocking & Timeouts

# %%
def sleeper(seconds, i=-1):
    if i != -1:
        print(f"{i}\t{seconds}s")
    time.sleep(seconds)

sleeper(12)

# %%
async def asleeper(seconds, i=-1):
    # time.sleep(seconds)
    if i != -1:
        print(f"a{i}\t{seconds}s")
    await asyncio.sleep(seconds)
    
await asleeper(12)

# %%
print("hello word")
# Out:
# hello word

# %%
loop = asyncio.get_event_loop()
# loop = asyncio.new_event_loop()
# aysncio.run()


loop.create_task(asleeper(123))
# Out:
# <Task pending name='Task-10' coro=<asleeper() running at /tmp/ipykernel_35607/3054092388.py:1>>

# %%
print("hello word")
# Out:
# hello word

# %%
done, pending = await asyncio.wait([asleeper(1), asleeper(123)], timeout=2)
done, pending
# Out:
# ({<Task finished name='Task-13' coro=<asleeper() done, defined at /tmp/ipykernel_35607/3054092388.py:1> result=None>},
#  {<Task pending name='Task-12' coro=<asleeper() running at /tmp/ipykernel_35607/3054092388.py:5> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7f9f10562b80>()]>>})

# %%
done
# Out:
# {<Task finished name='Task-13' coro=<asleeper() done, defined at /tmp/ipykernel_35607/3054092388.py:1> result=None>}

# %%
pending
# Out:
# {<Task pending name='Task-12' coro=<asleeper() running at /tmp/ipykernel_35607/3054092388.py:5> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7f9f10562b80>()]>>}

# %%
try:
    await asyncio.wait_for(asleeper(5), timeout=3)
except asyncio.TimeoutError:
    print("Task failed")
# Out:
# Task failed

# %%
async def asleeper_timeout(seconds, i=-1, timeout=4):
    # time.sleep(seconds)
    if i != -1:
        print(f"a{i}\t{seconds}s")
    await asyncio.wait_for(asyncio.sleep(seconds), timeout=timeout)
    
# await asleeper_timeout(12, timeout=1)

# %% [markdown]
# ## Scraping with Selenium - Synchronous
# New to selenium and web scraping? Watch [this series](https://kirr.co/dwy90n).

# %%
# !pip install requests_html pandas selenium webdriver-manager
# Out:
# Requirement already satisfied: requests_html in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: pandas in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (1.5.0)
# Requirement already satisfied: selenium in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (4.5.0)
# Requirement already satisfied: webdriver-manager in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (3.8.3)
# Requirement already satisfied: w3lib in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (2.0.1)
# Requirement already satisfied: fake-useragent in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (0.1.11)
# Requirement already satisfied: pyquery in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: requests in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (2.28.1)
# Requirement already satisfied: parse in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: bs4 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: pytz>=2020.1 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pandas) (2022.4)
# Requirement already satisfied: numpy>=1.20.3 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from selenium) (1.26.12)
# Requirement already satisfied: certifi>=2021.10.8 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio~=0.17 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: python-dotenv in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: tqdm in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: websockets<11.0,>=10.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (5.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.1)
# Requirement already satisfied: six>=1.5 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: idna in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.0.0rc9)
# Requirement already satisfied: attrs>=19.2.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: outcome in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: beautifulsoup4 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests_html) (2.3.2.post1)
# Requirement already satisfied: lxml>=2.1 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pyquery->requests_html) (4.9.1)
# Requirement already satisfied: cssselect>0.7.9 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from requests->requests_html) (2.1.1)
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/bin/python -m pip install --upgrade pip' command.

# %%
url = 'https://www.spoonflower.com/en/shop?on=fabric'

# %%
import re
import requests
from requests_html import HTML
import pandas as pd

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
def scraper(url):
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(url)
    return driver.page_source


# /en/fabric/7137786-genevieve-floral-by-crystal_walen
def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['slug']

# %%
content = scraper(url)
# Out:
# /tmp/ipykernel_35607/563692696.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
html_r = HTML(html=content)

fabric_links = [x for x in list(html_r.links) if x.startswith("/en/fabric")]

datas = []
for path in fabric_links:
    id_, slug_ = extract_id_slug(path)
    print(id_, slug_)
    data = {
        "id": id_,
        "slug": slug_,
        "path": path,
        "scraped": 0 # True / False -> 1 / 0 
    }
    datas.append(data)
# Out:
# 9544489 daisy-print-fabric-daisies-daisy-fabric-baby-fabric-spring-fabric-baby-girl-earthy-tan-by-charlottewinter
# 11112826 dragon-fire-rainbow-by-adenaj
# 2143712 rosey-document-by-peagreengirl
# 11125049 custom-colorway-groovy-mushroom-garden-rusty-orange-by-yesterdaycollection
# 8737001 chinoiserie-whimsy-blue-white-large-scale-pattern-by-pattern_garden
# 10569898 safari-new-by-ktscarlett_
# 10410859 mushroom-garden-linen-by-mypetalpress
# 9610524 large-le-jardin-art-nouveau-black-by-hnldesigns
# 8405290 fable-floral-teal-jumbo-by-nouveau_bohemian
# 11111052 avery-retro-floral-on-white-medium-scale-by-red_raspberry_design
# 7307966 art-deco-fleurs-d-or-by-j9design
# 7463028 seamless-watercolor-larger-leaves-pattern-1-by-daily_miracles
# 8345787 plain-white-solid-white-plain-unprinted-fabric-by-erin__kendal
# 9432598 modern-retro-floral-1970-muumuu-large-by-hnldesigns
# 9353509 mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor
# 5372926 light-blue-ocean-by-lauriekentdesigns
# 2300879 octopus-oasis-sea-by-willowlanetextiles
# 7137786 genevieve-floral-by-crystal_walen
# 12441406 large-aara-palm-floral-natural-pink-by-scarlette_soleil
# 9200337 flowers-honey-bees-large-blue-by-fernlesliestudio
# 3730688 william-morris-antiqued-pimpernel-original-on-black-by-peacoquettedesigns
# 7858049 1950-s-mid-century-modern-by-patternanddesign
# 6444170 catching-fireflies-by-thestorysmith
# 6675487 botanic-garden-by-irishvikingdesigns
# 9051641 watercolor-orchid-flower-pattern-by-watercolorpng
# 9709002 tiger-peacock-large-scale-by-sveta_aho
# 7522587 save-honey-bees-large-new-by-fernlesliestudio
# 11495120 wild-grasses-large-by-ninola-design
# 8589383 art-deco-swans-cream-on-black-by-katerhees
# 7936102 bats-hearts-pink-background-by-andrea_zuill
# 11483815 updated-large-scale-natural-habitat-bees-moths-wild-grass-flowers-please-read-description-by-ozdebayer
# 8197261 night-sky-stars-midnight-blue-space-night-sky-nursery-baby-boy-gender-neutral-nursery-by-at_the_cottage
# 7502637 fable-floral-black-jumbo-by-nouveau_bohemian
# 11388473 soft-blue-greens-on-white-by-danika_herrick
# 9792368 japanese-waves-by-sveta_aho
# 509390 spoonflower-color-map-by-spoonflower_help
# 8039248 forest-animal-hot-air-balloon-night-adventure-by-at_the_cottage
# 6754186 tropical-sunrise-by-floraryfabrics
# 6499779 molecular-divergence-sea-blue-coral-by-mimipinto
# 8744776 australian-eucalyptus-pink-orange-green-yellow-large-scale-by-unblinkstudio-by-jackietahara
# 10504027 watercolor-skull-moth-damask-by-rebelform
# 11512549 intergalactic-cats-rainbow-space-cat-vintage-multicolored-pets-80s-retro-outer-space-ufo-arcade-games-by-patricia_lima
# 10771343 cozy-cats-den-by-studioxtine
# 7502677 fable-floral-blush-jumbo-by-nouveau_bohemian
# 13153494 birds-daisies-teal-pink-by-katerhees
# 5279404 indigo-rain-by-crystal_walen
# 9565030 abstract-ocean-blue-by-daily_miracles
# 5544045 napoleonic-bees-faux-gilt-on-blackest-black-by-peacoquettedesigns
# 7368347 dear-clementine-oranges-teal-by-crystal_walen
# 9987142 daisy-dreams-jumbo-by-indybloomdesign
# 11484029 wild-grasses-by-ninola-design
# 7236018 native-eucalyptus-leaves-edition-1-fabric-wallpaper-by-erin__kendal
# 4150617 nod-house-bird-by-katerhees
# 6743135 rustic-fall-forest-animals-les-animaux-de-la-foret-by-rebecca_reck_art
# 703426 elephant-march-by-endemic
# 7967284 12-woodland-animals-baby-animals-autumn-forest-light-background-nursery-fabric-baby-girl-fabric-kids--by-utart
# 9155687 galaxy-deep-space-seamless-thousands-stars-starry-night-sky-by-rebecca_reck_art
# 1503057 william-morris-strawberry-thief-intense-by-peacoquettedesigns
# 8091225 dark-floral-black-roses-on-black-moody-floral-jumbo-size-by-eti-enne
# 9608189 art-nouveau-poppy-red-wallpaper-by-bamokreativ
# 11634796 heron-plants-light-medium-by-nina_leth
# 7661255 just-jellies-jellyfish-by-katerhees
# 10021703 sexy-mushrooms-by-cecilia_granata
# 9069096 black-cat-butterfly-garden-by-boszorka
# 6590171 mermaid-scales-by-elladorine
# 12906217 maximalist-folk-flowers-by-garabateo
# 8498488 boho-tropical-by-fineapple_pair
# 7812388 dnd-pattern-by-neonborealis
# 9954030 mushrooms-by-reinekke
# 10888687 microscopic-worlds-garabateo-by-garabateo
# 8223425 18-moody-florals-by-utart-vintage-home-decor-antique-botany-wallpaper-dark-roses-fabric-vintage-nosta-by-utart
# 10112497 large-scale-alien-abduction-toile-de-jouy-pattern-blue-by-somecallmebeth
# 1743921 william-morris-honeysuckle-by-peacoquettedesigns
# 11160216 midcentury-sunflowers-by-ottomanbrim
# 6782514 eame-s-wildflower-meadow-watercolor-floral-botanical-easter-spring-by-hipkiddesigns
# 7693817 orbs-squares-orange-cream-by-chicca_besso
# 8834187 mid-century-kaleidoscope-by-ceciliamok
# 10263472 golden-girl-9x9-by-indybloomdesign
# 8692520 bees-lemons-large-blue-original-colors-by-fernlesliestudio
# 6625245 sandstone-desert-by-wren_leyland
# 10148904 art-deco-swans-navy-12-by-katerhees
# 7748646 emerald-eden-by-catalinakim
# 12300699 cozy-night-sky-large-full-moon-stars-over-clouds-petal-solids-coordinate-navy-blue-indigo-gold-mustar-by-patricia_lima
# 13157281 nostalgic-vintage-tile-by-garabateo

# %%
df = pd.DataFrame(datas)
df.head()
# Out:
#          id                                               slug  \
# 0   9544489  daisy-print-fabric-daisies-daisy-fabric-baby-f...
# 1  11112826                      dragon-fire-rainbow-by-adenaj
# 2   2143712                     rosey-document-by-peagreengirl
# 3  11125049  custom-colorway-groovy-mushroom-garden-rusty-o...
# 4   8737001  chinoiserie-whimsy-blue-white-large-scale-patt...
#
#                                                 path  scraped
# 0  /en/fabric/9544489-daisy-print-fabric-daisies-...        0
# 1  /en/fabric/11112826-dragon-fire-rainbow-by-adenaj        0
# 2  /en/fabric/2143712-rosey-document-by-peagreengirl        0
# 3  /en/fabric/11125049-custom-colorway-groovy-mus...        0
# 4  /en/fabric/8737001-chinoiserie-whimsy-blue-whi...        0

# %%
df.to_csv("local.csv", index=False)

# %%
pd.read_csv("local.csv")
# Out:
#           id                                               slug  \
# 0    9544489  daisy-print-fabric-daisies-daisy-fabric-baby-f...
# 1   11112826                      dragon-fire-rainbow-by-adenaj
# 2    2143712                     rosey-document-by-peagreengirl
# 3   11125049  custom-colorway-groovy-mushroom-garden-rusty-o...
# 4    8737001  chinoiserie-whimsy-blue-white-large-scale-patt...
# ..       ...                                                ...
# 79   6625245                   sandstone-desert-by-wren_leyland
# 80  10148904                art-deco-swans-navy-12-by-katerhees
# 81   7748646                        emerald-eden-by-catalinakim
# 82  12300699  cozy-night-sky-large-full-moon-stars-over-clou...
# 83  13157281                nostalgic-vintage-tile-by-garabateo
#
#                                                  path  scraped
# 0   /en/fabric/9544489-daisy-print-fabric-daisies-...        0
# 1   /en/fabric/11112826-dragon-fire-rainbow-by-adenaj        0
# 2   /en/fabric/2143712-rosey-document-by-peagreengirl        0
# 3   /en/fabric/11125049-custom-colorway-groovy-mus...        0
# 4   /en/fabric/8737001-chinoiserie-whimsy-blue-whi...        0
# ..                                                ...      ...
# 79  /en/fabric/6625245-sandstone-desert-by-wren_le...        0
# 80  /en/fabric/10148904-art-deco-swans-navy-12-by-...        0
# 81     /en/fabric/7748646-emerald-eden-by-catalinakim        0
# 82  /en/fabric/12300699-cozy-night-sky-large-full-...        0
# 83  /en/fabric/13157281-nostalgic-vintage-tile-by-...        0
#
# [84 rows x 4 columns]

# %% [markdown]
# ## Asynchronous Scraping with `chromedriver` and `arsenic`
#
# [arsenic Docs](https://arsenic.readthedocs.io/en/latest/)

# %%
# !pip install arsenic
# Out:
# 4619.83s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: arsenic in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (21.8)
# Requirement already satisfied: structlog<21.0.0,>=20.1.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from arsenic) (20.2.0)
# Requirement already satisfied: aiohttp>=3 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from arsenic) (3.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from arsenic) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from aiohttp>=3->arsenic) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from aiohttp>=3->arsenic) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from aiohttp>=3->arsenic) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from aiohttp>=3->arsenic) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from aiohttp>=3->arsenic) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from aiohttp>=3->arsenic) (6.0.2)
# Requirement already satisfied: idna>=2.0 in /home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp>=3->arsenic) (3.4)
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/oswualdo.alquisiris/Documentos/RepoPersonal/venv8/bin/python -m pip install --upgrade pip' command.

# %%
# %%writefile async_scrape.py

import os
import asyncio
from arsenic import get_session, keys, browsers, services
import pandas as pd
from requests_html import HTML
import itertools
import re
import time
import pathlib

path = os.getcwd()


# /en/fabric/7137786-genevieve-floral-by-crystal_walen
async def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['slug']



async def get_links(body_content):
    html_r = HTML(html=body_content)
    fabric_links = [x for x in list(html_r.links) if x.startswith("/en/fabric")]
    datas = []
    for path in fabric_links:
        id_, slug_ = await extract_id_slug(path)
        data = {
            "id": id_,
            "slug": slug_,
            "path": path,
            "scraped": 0 # True / False -> 1 / 0 
        }
        datas.append(data)
    return datas

async def scraper(url):
    service = services.Chromedriver(binary=path+"/chromedriver")
    browser = browsers.Chrome()
    async with get_session(service, browser) as session:
        await session.get(url)
        body = await session.get_page_source()
        # print(body)
        return body


async def store_links_as_df_pickle(datas=[], name='links.pkl'):
    df = pd.DataFrame(datas)
    df.set_index('id', drop=True, inplace=True)
    df.to_pickle(name)
    return df
    
    
async def run(url):
    body_content = await scraper(url)
    links = await get_links(body_content)
    df = await store_links_as_df_pickle(links)
    return links
    
if __name__ == "__main__":
    url = 'https://www.spoonflower.com/en/shop?on=fabric'
    results = asyncio.run(run(url))
    print(results)
# Out:
# Overwriting async_scrape.py

# %%
# !python async_scrape.py
# Out:
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 57711
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# 2022-10-12 11:10.53 [info     ] request                        body={"capabilities": {"alwaysMatch": {"browserName": "chrome"}}} header={'Content-Type': 'application/json'} method=POST url=http://localhost:57711/session
# 2022-10-12 11:10.53 [info     ] response                       body={"capabilities": {"alwaysMatch": {"browserName": "chrome"}}} data={'value': {'capabilities': {'acceptInsecureCerts': False, 'browserName': 'chrome', 'browserVersion': '106.0.5249.103', 'chrome': {'chromedriverVersion': '106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569})', 'userDataDir': '/tmp/.com.google.Chrome.58B1ix'}, 'goog:chromeOptions': {'debuggerAddress': 'localhost:41737'}, 'networkConnectionEnabled': False, 'pageLoadStrategy': 'normal', 'platformName': 'linux', 'proxy': {}, 'setWindowRect': True, 'strictFileInteractability': False, 'timeouts': {'implicit': 0, 'pageLoad': 300000, 'script': 30000}, 'unhandledPromptBehavior': 'dismiss and notify', 'webauthn:extension:credBlob': True, 'webauthn:extension:largeBlob': True, 'webauthn:virtualAuthenticators': True}, 'sessionId': 'c8d332fd6ba385e4ce31217bedb2c772'}} method=POST response=<ClientResponse(http://localhost:57711/session) [200 OK]>
# <CIMultiDictProxy('Content-Length': '753', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache')>
#  url=http://localhost:57711/session
# 2022-10-12 11:10.53 [info     ] request                        body={"url": "https://www.spoonflower.com/en/shop?on=fabric"} header={'Content-Type': 'application/json'} method=POST url=http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772/url
# 2022-10-12 11:10.56 [info     ] response                       body={"url": "https://www.spoonflower.com/en/shop?on=fabric"} data={'value': None} method=POST response=<ClientResponse(http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772/url) [200 OK]>
# <CIMultiDictProxy('Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache')>
#  url=http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772/url
# 2022-10-12 11:10.56 [info     ] request                        body=None header=None method=GET url=http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772/source
# 2022-10-12 11:10.56 [info     ] response                       body=None data={'value': '<html lang="en"><head><meta charset="utf-8"><link rel="icon" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/favicon.ico"><meta name="viewport" content="width=device-width,initial-scale=1"><meta data-app-version="ssr-4.4.1-production"><meta http-equiv="X-UA-Compatible" content="IE=edge"><link rel="manifest" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/manifest.json"><link rel="preload" href="https://cdn.spoonflower.com/baerlauch/production/fonts/ParryPro-Normal.woff?display=swap" as="font" type="font/woff" crossorigin="anonymous"><link rel="preload" href="https://cdn.spoonflower.com/baerlauch/production/fonts/spoonflower-icons.ttf?20220328=?display=swap" as="font" type="font/ttf" crossorigin="anonymous"><link rel="preload" href="https://fonts.gstatic.com/s/lato/v22/S6uyw4BMUTPHjx4wXiWtFCc.woff2?display=swap" as="font" type="font/woff2" crossorigin="anonymous"><link rel="preload" href="https://fonts.gstatic.com/s/lato/v22/S6u9w4BMUTPHh7USSwiPGQ3q5d0.woff2?display=swap" as="font" type="font/woff2" crossorigin="anonymous"><link rel="preload" href="https://fonts.gstatic.com/s/lato/v22/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2?display=swap" as="font" type="font/woff2" crossorigin="anonymous"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Lato:ital,wght@0,300;0,400;0,700;1,300;1,400;1,700&amp;display=swap" crossorigin="anonymous"><title>Shop Over 1 Million Fabric Designs | Spoonflower</title>  <meta data-react-helmet="true" name="description" content="Over 1 million fabric designs. All designed by our community of artists, printed on-demand and available now. Shop cottons, canvas, knits, and so much more."><meta data-react-helmet="true" property="og:title" content="Wild grasses "><meta data-react-helmet="true" property="og:description" content="wildgrassesdc,wild grass,plants,countryside,nature,botanical,watercolor,artistic,home decor,cottagecore,watercolor flowers,watercolor floral,wallpaper,florals,fabric,sunshineydaysf,editorspicksbotanicalwallpaper"><meta data-react-helmet="true" property="og:image" content="https://garden.spoonflower.com/c/11484029/p/f/l/LS1zJPi3CknGvS3JBMPeYF2kI3LjOL9RXrPXrVs0c-Gj73tJrJnT/Wild%20grasses%20.jpg"><meta data-react-helmet="true" property="og:image:type" content="image/jpeg"><meta data-react-helmet="true" property="og:image:width" content="400"><meta data-react-helmet="true" property="og:image:height" content="400"><meta data-react-helmet="true" property="og:site_name" content="Spoonflower"><meta data-react-helmet="true" property="og:url" content="www.spoonflower.com/en/shop?on=fabric"> \n            \n            \n            <link data-chunk="ShopContainer" rel="preload" as="style" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/css/ShopContainer.08ec9f35.chunk.css">\n<link data-chunk="ShopContainer" rel="preload" as="style" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/css/0.b5ae274e.chunk.css">\n<link data-chunk="main" rel="preload" as="style" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/css/main.1d6270a6.chunk.css">\n<link data-chunk="main" rel="preload" as="script" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/js/62.95e956da.chunk.js">\n<link data-chunk="main" rel="preload" as="script" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/js/main.9dae0f4e.chunk.js">\n<link data-chunk="ShopContainer" rel="preload" as="script" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/js/0.6c07175d.chunk.js">\n<link data-chunk="ShopContainer" rel="preload" as="script" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production/static/js/1.29d37a27.chunk.js">\n<link data-chunk="ShopContainer" rel="preload" as="script" href="https://cdn.spoonflower.com/baerlauch-ssr/ssr-4.4.1-production ...
# <CIMultiDictProxy('Content-Length': '467780', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache')>
#  url=http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772/source
# 2022-10-12 11:10.56 [info     ] request                        body=None header=None method=DELETE url=http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772
# 2022-10-12 11:10.56 [info     ] response                       body=None data={'value': None} method=DELETE response=<ClientResponse(http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772) [200 OK]>
# <CIMultiDictProxy('Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache')>
#  url=http://localhost:57711/session/c8d332fd6ba385e4ce31217bedb2c772
# [{'id': '9353509', 'slug': 'mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor', 'path': '/en/fabric/9353509-mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor', 'scraped': 0}, {'id': '5372926', 'slug': 'light-blue-ocean-by-lauriekentdesigns', 'path': '/en/fabric/5372926-light-blue-ocean-by-lauriekentdesigns', 'scraped': 0}, {'id': '8834187', 'slug': 'mid-century-kaleidoscope-by-ceciliamok', 'path': '/en/fabric/8834187-mid-century-kaleidoscope-by-ceciliamok', 'scraped': 0}, {'id': '12441406', 'slug': 'large-aara-palm-floral-natural-pink-by-scarlette_soleil', 'path': '/en/fabric/12441406-large-aara-palm-floral-natural-pink-by-scarlette_soleil', 'scraped': 0}, {'id': '6782514', 'slug': 'eame-s-wildflower-meadow-watercolor-floral-botanical-easter-spring-by-hipkiddesigns', 'path': '/en/fabric/6782514-eame-s-wildflower-meadow-watercolor-floral-botanical-easter-spring-by-hipkiddesigns', 'scraped': 0}, {'id': '8345787', 'slug': 'plain-white-solid-white-plain-unprinted-fabric-by-erin__kendal', 'path': '/en/fabric/8345787-plain-white-solid-white-plain-unprinted-fabric-by-erin__kendal', 'scraped': 0}, {'id': '13153494', 'slug': 'birds-daisies-teal-pink-by-katerhees', 'path': '/en/fabric/13153494-birds-daisies-teal-pink-by-katerhees', 'scraped': 0}, {'id': '11160216', 'slug': 'midcentury-sunflowers-by-ottomanbrim', 'path': '/en/fabric/11160216-midcentury-sunflowers-by-ottomanbrim', 'scraped': 0}, {'id': '3730688', 'slug': 'william-morris-antiqued-pimpernel-original-on-black-by-peacoquettedesigns', 'path': '/en/fabric/3730688-william-morris-antiqued-pimpernel-original-on-black-by-peacoquettedesigns', 'scraped': 0}, {'id': '5279404', 'slug': 'indigo-rain-by-crystal_walen', 'path': '/en/fabric/5279404-indigo-rain-by-crystal_walen', 'scraped': 0}, {'id': '4150617', 'slug': 'nod-house-bird-by-katerhees', 'path': '/en/fabric/4150617-nod-house-bird-by-katerhees', 'scraped': 0}, {'id': '1503057', 'slug': 'william-morris-strawberry-thief-intense-by-peacoquettedesigns', 'path': '/en/fabric/1503057-william-morris-strawberry-thief-intense-by-peacoquettedesigns', 'scraped': 0}, {'id': '9608189', 'slug': 'art-nouveau-poppy-red-wallpaper-by-bamokreativ', 'path': '/en/fabric/9608189-art-nouveau-poppy-red-wallpaper-by-bamokreativ', 'scraped': 0}, {'id': '11495120', 'slug': 'wild-grasses-large-by-ninola-design', 'path': '/en/fabric/11495120-wild-grasses-large-by-ninola-design', 'scraped': 0}, {'id': '7858049', 'slug': '1950-s-mid-century-modern-by-patternanddesign', 'path': '/en/fabric/7858049-1950-s-mid-century-modern-by-patternanddesign', 'scraped': 0}, {'id': '11125049', 'slug': 'custom-colorway-groovy-mushroom-garden-rusty-orange-by-yesterdaycollection', 'path': '/en/fabric/11125049-custom-colorway-groovy-mushroom-garden-rusty-orange-by-yesterdaycollection', 'scraped': 0}, {'id': '9987142', 'slug': 'daisy-dreams-jumbo-by-indybloomdesign', 'path': '/en/fabric/9987142-daisy-dreams-jumbo-by-indybloomdesign', 'scraped': 0}, {'id': '7936102', 'slug': 'bats-hearts-pink-background-by-andrea_zuill', 'path': '/en/fabric/7936102-bats-hearts-pink-background-by-andrea_zuill', 'scraped': 0}, {'id': '9155687', 'slug': 'galaxy-deep-space-seamless-thousands-stars-starry-night-sky-by-rebecca_reck_art', 'path': '/en/fabric/9155687-galaxy-deep-space-seamless-thousands-stars-starry-night-sky-by-rebecca_reck_art', 'scraped': 0}, {'id': '11484029', 'slug': 'wild-grasses-by-ninola-design', 'path': '/en/fabric/11484029-wild-grasses-by-ninola-design', 'scraped': 0}, {'id': '10504027', 'slug': 'watercolor-skull-moth-damask-by-rebelform', 'path': '/en/fabric/10504027-watercolor-skull-moth-damask-by-rebelform', 'scraped': 0}, {'id': '8405290', 'slug': 'fable-floral-teal-jumbo-by-nouveau_bohemian', 'path': '/en/fabric/8405290-fable-floral-teal-jumbo-by-nouveau_bohemian', 'scraped': 0}, {'id': '7693817', 'slug': 'orbs-squares-orange-cream-by-chicca_besso', 'path': '/en/fabric/7693817-orbs-squares-orange-cream- ...

# %%
name = 'links.pkl'
df = pd.read_pickle(name)
df.head()
# Out:
#                                                        slug  \
# id
# 9353509   mustard-mud-cloth-arrow-cross-dot-mudcloth-hom...
# 5372926               light-blue-ocean-by-lauriekentdesigns
# 8834187              mid-century-kaleidoscope-by-ceciliamok
# 12441406  large-aara-palm-floral-natural-pink-by-scarlet...
# 6782514   eame-s-wildflower-meadow-watercolor-floral-bot...
#
#                                                        path  scraped
# id
# 9353509   /en/fabric/9353509-mustard-mud-cloth-arrow-cro...        0
# 5372926   /en/fabric/5372926-light-blue-ocean-by-lauriek...        0
# 8834187   /en/fabric/8834187-mid-century-kaleidoscope-by...        0
# 12441406  /en/fabric/12441406-large-aara-palm-floral-nat...        0
# 6782514   /en/fabric/6782514-eame-s-wildflower-meadow-wa...        0

# %%
df.shape
# Out:
# (84, 3)

# %% [markdown]
# ## Hide `arsenic` Logs

# %%
# !pip install structlog
# Out:
# Requirement already satisfied: structlog in /Users/cfe/.local/share/virtualenvs/supercharged-tjIFpWCv/lib/python3.8/site-packages (20.1.0)
# Requirement already satisfied: six in /Users/cfe/.local/share/virtualenvs/supercharged-tjIFpWCv/lib/python3.8/site-packages (from structlog) (1.15.0)

# %%
# %%writefile async_scrape.py

import os
import asyncio
from arsenic import get_session, keys, browsers, services
import pandas as pd
from requests_html import HTML
import itertools
import re
import time
import pathlib

import logging
import structlog # pip install structlog

from pathlib import Path

path = os.getcwd()

def abspath(file):
    return str(Path(__file__).parent.absolute() / file)

def set_arsenic_log_level(level = logging.WARNING):
    # Create logger
    logger = logging.getLogger('arsenic')

    # We need factory, to return application-wide logger
    def logger_factory():
        return logger

    structlog.configure(logger_factory=logger_factory)
    logger.setLevel(level)


# /en/fabric/7137786-genevieve-floral-by-crystal_walen
async def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['slug']



async def get_links(body_content):
    html_r = HTML(html=body_content)
    fabric_links = [x for x in list(html_r.links) if x.startswith("/en/fabric")]
    datas = []
    for path in fabric_links:
        id_, slug_ = await extract_id_slug(path)
        data = {
            "id": id_,
            "slug": slug_,
            "path": path,
            "scraped": 0 # True / False -> 1 / 0 
        }
        datas.append(data)
    return datas

async def scraper(url):
    service = services.Chromedriver(binary=path+"/chromedriver")
    browser = browsers.Chrome()
    async with get_session(service, browser) as session:
        await session.get(url)
        body = await session.get_page_source()
        # print(body)
        return body


async def store_links_as_df_pickle(datas=[], name='links.pkl'):
    df = pd.DataFrame(datas)
    df.set_index('id', drop=True, inplace=True)
    df.to_pickle(name)
    return df
    
    
async def run(url):
    body_content = await scraper(url)
    links = await get_links(body_content)
    df = await store_links_as_df_pickle(links)
    return links
    
if __name__ == "__main__":
    set_arsenic_log_level()
    url = 'https://www.spoonflower.com/en/shop?on=fabric'
    results = asyncio.run(run(url))
    print(results)
# Out:
# Overwriting async_scrape.py

# %%
# !python async_scrape.py
# Out:
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 36287
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# [{'id': '8834187', 'slug': 'mid-century-kaleidoscope-by-ceciliamok', 'path': '/en/fabric/8834187-mid-century-kaleidoscope-by-ceciliamok', 'scraped': 0}, {'id': '10569898', 'slug': 'safari-new-by-ktscarlett_', 'path': '/en/fabric/10569898-safari-new-by-ktscarlett_', 'scraped': 0}, {'id': '9610524', 'slug': 'large-le-jardin-art-nouveau-black-by-hnldesigns', 'path': '/en/fabric/9610524-large-le-jardin-art-nouveau-black-by-hnldesigns', 'scraped': 0}, {'id': '9544489', 'slug': 'daisy-print-fabric-daisies-daisy-fabric-baby-fabric-spring-fabric-baby-girl-earthy-tan-by-charlottewinter', 'path': '/en/fabric/9544489-daisy-print-fabric-daisies-daisy-fabric-baby-fabric-spring-fabric-baby-girl-earthy-tan-by-charlottewinter', 'scraped': 0}, {'id': '8345787', 'slug': 'plain-white-solid-white-plain-unprinted-fabric-by-erin__kendal', 'path': '/en/fabric/8345787-plain-white-solid-white-plain-unprinted-fabric-by-erin__kendal', 'scraped': 0}, {'id': '12441406', 'slug': 'large-aara-palm-floral-natural-pink-by-scarlette_soleil', 'path': '/en/fabric/12441406-large-aara-palm-floral-natural-pink-by-scarlette_soleil', 'scraped': 0}, {'id': '6590171', 'slug': 'mermaid-scales-by-elladorine', 'path': '/en/fabric/6590171-mermaid-scales-by-elladorine', 'scraped': 0}, {'id': '13153494', 'slug': 'birds-daisies-teal-pink-by-katerhees', 'path': '/en/fabric/13153494-birds-daisies-teal-pink-by-katerhees', 'scraped': 0}, {'id': '9608189', 'slug': 'art-nouveau-poppy-red-wallpaper-by-bamokreativ', 'path': '/en/fabric/9608189-art-nouveau-poppy-red-wallpaper-by-bamokreativ', 'scraped': 0}, {'id': '6675487', 'slug': 'botanic-garden-by-irishvikingdesigns', 'path': '/en/fabric/6675487-botanic-garden-by-irishvikingdesigns', 'scraped': 0}, {'id': '7812388', 'slug': 'dnd-pattern-by-neonborealis', 'path': '/en/fabric/7812388-dnd-pattern-by-neonborealis', 'scraped': 0}, {'id': '10112497', 'slug': 'large-scale-alien-abduction-toile-de-jouy-pattern-blue-by-somecallmebeth', 'path': '/en/fabric/10112497-large-scale-alien-abduction-toile-de-jouy-pattern-blue-by-somecallmebeth', 'scraped': 0}, {'id': '11160216', 'slug': 'midcentury-sunflowers-by-ottomanbrim', 'path': '/en/fabric/11160216-midcentury-sunflowers-by-ottomanbrim', 'scraped': 0}, {'id': '9709002', 'slug': 'tiger-peacock-large-scale-by-sveta_aho', 'path': '/en/fabric/9709002-tiger-peacock-large-scale-by-sveta_aho', 'scraped': 0}, {'id': '6625245', 'slug': 'sandstone-desert-by-wren_leyland', 'path': '/en/fabric/6625245-sandstone-desert-by-wren_leyland', 'scraped': 0}, {'id': '5279404', 'slug': 'indigo-rain-by-crystal_walen', 'path': '/en/fabric/5279404-indigo-rain-by-crystal_walen', 'scraped': 0}, {'id': '7661255', 'slug': 'just-jellies-jellyfish-by-katerhees', 'path': '/en/fabric/7661255-just-jellies-jellyfish-by-katerhees', 'scraped': 0}, {'id': '10263472', 'slug': 'golden-girl-9x9-by-indybloomdesign', 'path': '/en/fabric/10263472-golden-girl-9x9-by-indybloomdesign', 'scraped': 0}, {'id': '9954030', 'slug': 'mushrooms-by-reinekke', 'path': '/en/fabric/9954030-mushrooms-by-reinekke', 'scraped': 0}, {'id': '5372926', 'slug': 'light-blue-ocean-by-lauriekentdesigns', 'path': '/en/fabric/5372926-light-blue-ocean-by-lauriekentdesigns', 'scraped': 0}, {'id': '10148904', 'slug': 'art-deco-swans-navy-12-by-katerhees', 'path': '/en/fabric/10148904-art-deco-swans-navy-12-by-katerhees', 'scraped': 0}, {'id': '3730688', 'slug': 'william-morris-antiqued-pimpernel-original-on-black-by-peacoquettedesigns', 'path': '/en/fabric/3730688-william-morris-antiqued-pimpernel-original-on-black-by-peacoquettedesigns', 'scraped': 0}, {'id': '10021703', 'slug': 'sexy-mushrooms-by-cecilia_granata', 'path': '/en/fabric/10021703-sexy-mushrooms-by-cecilia_granata', 'scraped': 0}, {'id': '9353509', 'slug': 'mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor', 'path': '/en/fabric/9353509-mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor', 'scraped': 0}, {'id': '7502677', 'slug': 'fa ...

# %% [markdown]
# ## Async Data with Pandas

# %%
# %%writefile async_scrape.py

import os
import asyncio
from arsenic import get_session, keys, browsers, services
import pandas as pd
from requests_html import HTML
import itertools
import re
import time
import pathlib

import logging
import structlog # pip install structlog

path = os.getcwd()

def set_arsenic_log_level(level = logging.WARNING):
    # Create logger
    logger = logging.getLogger('arsenic')

    # We need factory, to return application-wide logger
    def logger_factory():
        return logger

    structlog.configure(logger_factory=logger_factory)
    logger.setLevel(level)


# /en/fabric/7137786-genevieve-floral-by-crystal_walen
async def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['slug']



async def get_links(body_content):
    html_r = HTML(html=body_content)
    fabric_links = [x for x in list(html_r.links) if x.startswith("/en/fabric")]
    datas = []
    for path in fabric_links:
        id_, slug_ = await extract_id_slug(path)
        data = {
            "id": id_,
            "slug": slug_,
            "path": path,
            "scraped": 0 # True / False -> 1 / 0 
        }
        datas.append(data)
    return datas

async def scraper(url):
    service = services.Chromedriver(binary=path+"/chromedriver")
    browser = browsers.Chrome()
    async with get_session(service, browser) as session:
        await session.get(url)
        body = await session.get_page_source()
        # print(body)
        return body


def store_links_as_df_pickle(datas=[], name='links.pkl'):
    new_df = pd.DataFrame(datas)
    og_df = pd.DataFrame([{'id': 0}])
    if pathlib.Path(name).exists():
        og_df = pd.read_pickle(name) # read_csv
    df = pd.concat([og_df, new_df])
    df.reset_index(inplace=True, drop=False)
    df = df[['id', 'slug', 'path', 'scraped']]
    df = df.loc[~df.id.duplicated(keep='first')]
    # df.set_index('id', inplace=True, drop=True)
    df.dropna(inplace=True)
    df.to_pickle(name)
    return df
    
    
async def run(url):
    body_content = await scraper(url)
    links = await get_links(body_content)
    return links
    
if __name__ == "__main__":
    set_arsenic_log_level()
    url = 'https://www.spoonflower.com/en/shop?on=fabric'
    name = "link.pkl"
    results = asyncio.run(run(url))
    df = store_links_as_df_pickle(results, name=name)
    print(df.head())
# Out:
# Overwriting async_scrape.py

# %%
# !python async_scrape.py
# Out:
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 44677
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
#          id  ... scraped
# 1   8039248  ...     0.0
# 2  10569898  ...     0.0
# 3   1503057  ...     0.0
# 4   8737001  ...     0.0
# 5   9792368  ...     0.0
#
# [5 rows x 4 columns]

# %%
df = pd.read_pickle("link.pkl")
df.shape
# Out:
# (84, 4)

# %%
df.head(n=10)
# Out:
#           id                                               slug  \
# 1    8039248  forest-animal-hot-air-balloon-night-adventure-...
# 2   10569898                          safari-new-by-ktscarlett_
# 3    1503057  william-morris-strawberry-thief-intense-by-pea...
# 4    8737001  chinoiserie-whimsy-blue-white-large-scale-patt...
# 5    9792368                        japanese-waves-by-sveta_aho
# 6    8091225  dark-floral-black-roses-on-black-moody-floral-...
# 7    9432598  modern-retro-floral-1970-muumuu-large-by-hnlde...
# 8    7502677       fable-floral-blush-jumbo-by-nouveau_bohemian
# 9    8834187             mid-century-kaleidoscope-by-ceciliamok
# 10  11111052  avery-retro-floral-on-white-medium-scale-by-re...
#
#                                                  path  scraped
# 1   /en/fabric/8039248-forest-animal-hot-air-ballo...      0.0
# 2       /en/fabric/10569898-safari-new-by-ktscarlett_      0.0
# 3   /en/fabric/1503057-william-morris-strawberry-t...      0.0
# 4   /en/fabric/8737001-chinoiserie-whimsy-blue-whi...      0.0
# 5      /en/fabric/9792368-japanese-waves-by-sveta_aho      0.0
# 6   /en/fabric/8091225-dark-floral-black-roses-on-...      0.0
# 7   /en/fabric/9432598-modern-retro-floral-1970-mu...      0.0
# 8   /en/fabric/7502677-fable-floral-blush-jumbo-by...      0.0
# 9   /en/fabric/8834187-mid-century-kaleidoscope-by...      0.0
# 10  /en/fabric/11111052-avery-retro-floral-on-whit...      0.0

# %% [markdown]
# ## Prepare to Scrape Multiple URLs

# %%
start = time.time()
iteration_times = [1, 3, 2, 1]


async def asleeper_timeout(seconds, i=-1, timeout=4):
    # time.sleep(seconds)
    if i != -1:
        print(f"a{i}\t{seconds}s")
    await asyncio.wait_for(asyncio.sleep(seconds), timeout=timeout)
    ellap = time.time() - start
    print(f"{i} done {ellap}")


async def a_run():
    results = []
    for i, second in enumerate(iteration_times):
        results.append(
            asyncio.create_task(asleeper_timeout(second, i=i))
        )
    return results
    
results = await a_run()
print(results)
end = time.time() - start

print(end)
# Out:
# [<Task pending name='Task-17' coro=<asleeper_timeout() running at /tmp/ipykernel_35607/619623914.py:5>>, <Task pending name='Task-18' coro=<asleeper_timeout() running at /tmp/ipykernel_35607/619623914.py:5>>, <Task pending name='Task-19' coro=<asleeper_timeout() running at /tmp/ipykernel_35607/619623914.py:5>>, <Task pending name='Task-20' coro=<asleeper_timeout() running at /tmp/ipykernel_35607/619623914.py:5>>]
# 0.0005147457122802734
# a0	1s
# a1	3s
# a2	2s
# a3	1s
# 0 done 1.0053787231445312
# 3 done 1.0055482387542725
# 2 done 2.006096601486206
# 1 done 3.00590181350708

# %%
# %%writefile async_scrape.py

import os
import asyncio
from arsenic import get_session, keys, browsers, services
import pandas as pd
from requests_html import HTML
import itertools
import re
import time
import pathlib

import logging
import structlog # pip install structlog

path = os.getcwd()




def store_links_as_df_pickle(datas=[], name='links.pkl'):
    new_df = pd.DataFrame(datas)
    og_df = pd.DataFrame([{'id': 0}])
    if pathlib.Path(name).exists():
        og_df = pd.read_pickle(name) # read_csv
    df = pd.concat([og_df, new_df])
    df.reset_index(inplace=True, drop=False)
    df = df[['id', 'slug', 'path', 'scraped']]
    df = df.loc[~df.id.duplicated(keep='first')]
    # df.set_index('id', inplace=True, drop=True)
    df.dropna(inplace=True)
    df.to_pickle(name)
    return df


def set_arsenic_log_level(level = logging.WARNING):
    # Create logger
    logger = logging.getLogger('arsenic')

    # We need factory, to return application-wide logger
    def logger_factory():
        return logger

    structlog.configure(logger_factory=logger_factory)
    logger.setLevel(level)


# /en/fabric/7137786-genevieve-floral-by-crystal_walen
async def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['slug']



async def get_links(body_content):
    html_r = HTML(html=body_content)
    fabric_links = [x for x in list(html_r.links) if x.startswith("/en/fabric")]
    datas = []
    for path in fabric_links:
        id_, slug_ = await extract_id_slug(path)
        data = {
            "id": id_,
            "slug": slug_,
            "path": path,
            "scraped": 0 # True / False -> 1 / 0 
        }
        datas.append(data)
    return datas

async def scraper(url, i=-1, timeout=60, start=None):
    service = services.Chromedriver(binary=path+"/chromedriver")
    browser = browsers.Chrome()
    async with get_session(service, browser) as session:
        try:
            await asyncio.wait_for(session.get(url), timeout=timeout)
        except asyncio.TimeoutError:
            return []
        body = await session.get_page_source()
        links = await get_links(body)
        if start != None:
            end = time.time() - start
            print(f'{i} took {end} seconds')
        # print(body)
        return links


async def run(urls, timeout=60, start=None):
    results = []
    for i, url in enumerate(urls):
        results.append(
            asyncio.create_task(scraper(url, i=i, timeout=60, start=start))
        )
    list_of_links = await asyncio.gather(*results)
    return list_of_links

if __name__ == "__main__":
    set_arsenic_log_level()
    start = time.time()
    urls = ['https://www.spoonflower.com/en/shop?on=fabric', 
            'https://www.spoonflower.com/en/fabric/6444170-catching-fireflies-by-thestorysmith']
    name = "link.pkl"
    results = asyncio.run(run(urls, start=start))
    print(len(results))
    end = time.time() - start
    print(f'total time is {end}')
#     df = store_links_as_df_pickle(results, name=name)
#     print(df.head())
# Out:
# Overwriting async_scrape.py

# %%
# !python async_scrape.py
# Out:
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 53573
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 57835
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# 0 took 3.5485942363739014 seconds
# 1 took 4.997168064117432 seconds
# 2
# total time is 5.101632356643677

# %% [markdown]
# ## Extract Product Data

# %%
import re
import requests
from requests_html import HTML
import pandas as pd
from urllib.parse import urlparse
import time

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager


def scraper(url):
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(url)
    time.sleep(5)
    return driver.page_source

def extract_id_slug(url_path):
    path = url_path
    if path.startswith('http'):
        parsed_url = urlparse(path)
        path = parsed_url.path
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, path)
    if not group:
        return None, None, path
    return group['id'], group['slug'], path

# %%
url = 'https://www.spoonflower.com/en/fabric/6444170-catching-fireflies-by-thestorysmith'

html_str = scraper(url)
content = HTML(html=html_str)
# Out:
# /tmp/ipykernel_35607/2991718406.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
def get_product_data(url, content):
    id_, slug_, path = extract_id_slug(url)
    titleEl = content.find(".design-title", first=True)
    data = {
        'id': id_,
        'slug': slug_,
        'path': path,
    }
    title = None
    if titleEl == None:
        return data
    title = titleEl.text
    data['title'] = title
    sizeEl = content.find("#fabric-size", first=True)
    size = None
    if sizeEl != None:
        size = sizeEl.text
    data['size'] = size
    price_parent_el = content.find('.b-item-price', first=True)
    price_el = price_parent_el.find('.visuallyhidden', first=True)
    for i in price_el.element.iterchildren():
        attrs = dict(**i.attrib)
        attrs_keys = list(attrs.keys())
        data[i.attrib['itemprop']] = i.attrib[attrs_keys[0]]
    return data

# %%
get_product_data(url, content)
# Out:
# {'id': '6444170',
#  'slug': 'catching-fireflies-by-thestorysmith',
#  'path': '/en/fabric/6444170-catching-fireflies-by-thestorysmith',
#  'title': 'Catching Fireflies',
#  'size': None,
#  'price': 'price',
#  'priceCurrency': 'priceCurrency',
#  'priceValidUntil': 'priceValidUntil'}

# %%
# url2 = "https://www.spoonflower.com/en/fabric/7175195-golden-watercolor-rainbow-rows-5-by-anniemontgomerydesign?fabric=petal_signature_cotton"
# html_str2 = scraper(url2)
# content2 = HTML(html=html_str2)
# get_product_data(url2, content2)
# Out:
# {'id': '7175195',
#  'slug': 'golden-watercolor-rainbow-rows-5-by-anniemontgomerydesign',
#  'path': '/en/fabric/7175195-golden-watercolor-rainbow-rows-5-by-anniemontgomerydesign',
#  'title': 'Golden Watercolor Rainbow Rows .5"'}

# %% [markdown]
# ## Async Product Data Extraction

# %%
# %%writefile async_scrape.py

import os
import asyncio
from arsenic import get_session, keys, browsers, services
import pandas as pd
from requests_html import HTML
import itertools
import re
import time
import pathlib
from urllib.parse import urlparse

import logging
import structlog # pip install structlog

path = os.getcwd()


def store_links_as_df_pickle(datas=[], name='links.pkl'):
    new_df = pd.DataFrame(datas)
    og_df = pd.DataFrame([{'id': 0}])
    if pathlib.Path(name).exists():
        og_df = pd.read_pickle(name) # read_csv
    df = pd.concat([og_df, new_df])
    df.reset_index(inplace=True, drop=False)
    df = df[['id', 'slug', 'path', 'scraped']]
    df = df.loc[~df.id.duplicated(keep='first')]
    # df.set_index('id', inplace=True, drop=True)
    df.dropna(inplace=True)
    df.to_pickle(name)
    return df


def set_arsenic_log_level(level = logging.WARNING):
    # Create logger
    logger = logging.getLogger('arsenic')

    # We need factory, to return application-wide logger
    def logger_factory():
        return logger

    structlog.configure(logger_factory=logger_factory)
    logger.setLevel(level)


# /en/fabric/7137786-genevieve-floral-by-crystal_walen
async def extract_id_slug(url_path):
    path = url_path
    if path.startswith('http'):
        parsed_url = urlparse(path)
        path = parsed_url.path
    regex = r"^[^\s]+/(?P<id>\d+)-(?P<slug>[\w_-]+)$"
    group = re.match(regex, path)
    if not group:
        return None, None, path
    return group['id'], group['slug'], path



async def get_product_data(url, content):
    id_, slug_, path = await extract_id_slug(url)
    titleEl = content.find(".design-title", first=True)
    data = {
        'id': id_,
        'slug': slug_,
        'path': path,
    }
    title = None
    if titleEl == None:
        return data
    title = titleEl.text
    data['title'] = title
    sizeEl = content.find("#fabric-size", first=True)
    size = None
    if sizeEl != None:
        size = sizeEl.text
    data['size'] = size
    price_parent_el = content.find('.b-item-price', first=True)
    price_el = price_parent_el.find('.visuallyhidden', first=True)
    for i in price_el.element.iterchildren():
        attrs = dict(**i.attrib)
        attrs_keys = list(attrs.keys())
        data[i.attrib['itemprop']] = i.attrib[attrs_keys[0]]
    return data

async def get_parsable_html(body_html_str):
    return HTML(html=body_html_str)

async def get_links(html_r):
    fabric_links = [x for x in list(html_r.links) if x.startswith("/en/fabric")]
    datas = []
    for path in fabric_links:
        id_, slug_, _ = await extract_id_slug(path)
        data = {
            "id": id_,
            "slug": slug_,
            "path": path,
            "scraped": 0 # True / False -> 1 / 0 
        }
        datas.append(data)
    return datas

async def scraper(url, i=-1, timeout=60, start=None):
    service = services.Chromedriver(binary=path+"/chromedriver")
    browser = browsers.Chrome()
    async with get_session(service, browser) as session:
        try:
            await asyncio.wait_for(session.get(url), timeout=timeout)
        except asyncio.TimeoutError:
            return []
        await asyncio.sleep(10)
        body = await session.get_page_source() # save this locally??
        content = await get_parsable_html(body) 
        links = await get_links(content)
        product_data = await get_product_data(url, content)
        if start != None:
            end = time.time() - start
            print(f'{i} took {end} seconds')
        # print(body)
        dataset = {
            "links": links,
            "product_data": product_data
        }
        return dataset


async def run(urls, timeout=60, start=None):
    results = []
    for i, url in enumerate(urls):
        results.append(
            asyncio.create_task(scraper(url, i=i, timeout=60, start=start))
        )
    list_of_links = await asyncio.gather(*results)
    return list_of_links

if __name__ == "__main__":
    set_arsenic_log_level()
    start = time.time()
    urls = ['https://www.spoonflower.com/en/shop?on=fabric', 
            'https://www.spoonflower.com/en/fabric/6444170-catching-fireflies-by-thestorysmith']
    name = "link.pkl"
    results = asyncio.run(run(urls, start=start))
    print(results)
    end = time.time() - start
    print(f'total time is {end}')
#     df = store_links_as_df_pickle(results, name=name)
#     print(df.head())
# Out:
# Overwriting async_scrape.py

# %%
# !python async_scrape.py
# Out:
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 47343
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# Starting ChromeDriver 106.0.5249.61 (511755355844955cd3e264779baf0dd38212a4d0-refs/branch-heads/5249@{#569}) on port 48207
# Only local connections are allowed.
# Please see https://chromedriver.chromium.org/security-considerations for suggestions on keeping ChromeDriver safe.
# ChromeDriver was started successfully.
# 0 took 14.407435417175293 seconds
# 1 took 15.427944660186768 seconds
# [{'links': [{'id': '11483815', 'slug': 'updated-large-scale-natural-habitat-bees-moths-wild-grass-flowers-please-read-description-by-ozdebayer', 'path': '/en/fabric/11483815-updated-large-scale-natural-habitat-bees-moths-wild-grass-flowers-please-read-description-by-ozdebayer', 'scraped': 0}, {'id': '7661255', 'slug': 'just-jellies-jellyfish-by-katerhees', 'path': '/en/fabric/7661255-just-jellies-jellyfish-by-katerhees', 'scraped': 0}, {'id': '509390', 'slug': 'spoonflower-color-map-by-spoonflower_help', 'path': '/en/fabric/509390-spoonflower-color-map-by-spoonflower_help', 'scraped': 0}, {'id': '11484029', 'slug': 'wild-grasses-by-ninola-design', 'path': '/en/fabric/11484029-wild-grasses-by-ninola-design', 'scraped': 0}, {'id': '9792368', 'slug': 'japanese-waves-by-sveta_aho', 'path': '/en/fabric/9792368-japanese-waves-by-sveta_aho', 'scraped': 0}, {'id': '10888687', 'slug': 'microscopic-worlds-garabateo-by-garabateo', 'path': '/en/fabric/10888687-microscopic-worlds-garabateo-by-garabateo', 'scraped': 0}, {'id': '9608189', 'slug': 'art-nouveau-poppy-red-wallpaper-by-bamokreativ', 'path': '/en/fabric/9608189-art-nouveau-poppy-red-wallpaper-by-bamokreativ', 'scraped': 0}, {'id': '9954030', 'slug': 'mushrooms-by-reinekke', 'path': '/en/fabric/9954030-mushrooms-by-reinekke', 'scraped': 0}, {'id': '9565030', 'slug': 'abstract-ocean-blue-by-daily_miracles', 'path': '/en/fabric/9565030-abstract-ocean-blue-by-daily_miracles', 'scraped': 0}, {'id': '7522587', 'slug': 'save-honey-bees-large-new-by-fernlesliestudio', 'path': '/en/fabric/7522587-save-honey-bees-large-new-by-fernlesliestudio', 'scraped': 0}, {'id': '6590171', 'slug': 'mermaid-scales-by-elladorine', 'path': '/en/fabric/6590171-mermaid-scales-by-elladorine', 'scraped': 0}, {'id': '9353509', 'slug': 'mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor', 'path': '/en/fabric/9353509-mustard-mud-cloth-arrow-cross-dot-mudcloth-home-decor-tribal-lad19-by-littlearrowdecor', 'scraped': 0}, {'id': '7137786', 'slug': 'genevieve-floral-by-crystal_walen', 'path': '/en/fabric/7137786-genevieve-floral-by-crystal_walen', 'scraped': 0}, {'id': '8834187', 'slug': 'mid-century-kaleidoscope-by-ceciliamok', 'path': '/en/fabric/8834187-mid-century-kaleidoscope-by-ceciliamok', 'scraped': 0}, {'id': '1503057', 'slug': 'william-morris-strawberry-thief-intense-by-peacoquettedesigns', 'path': '/en/fabric/1503057-william-morris-strawberry-thief-intense-by-peacoquettedesigns', 'scraped': 0}, {'id': '703426', 'slug': 'elephant-march-by-endemic', 'path': '/en/fabric/703426-elephant-march-by-endemic', 'scraped': 0}, {'id': '9610524', 'slug': 'large-le-jardin-art-nouveau-black-by-hnldesigns', 'path': '/en/fabric/9610524-large-le-jardin-art-nouveau-black-by-hnldesigns', 'scraped': 0}, {'id': '10569898', 'slug': 'safari-new-by-ktscarlett_', 'path': '/en/fabric/10569898-safari-new-by-ktscarlett_', 'scraped': 0}, {'id': '7236018', 'slug': 'native-eucalyptus-leaves-edition-1-fabric-wallpaper-by-erin__kendal', 'path': '/en/fabric/7236018-native-eucalyptus-leaves-edition-1-fabric-wallpaper-by-erin__kendal', 'scraped': 0}, {'id': '9544489', 'slug': 'daisy-print-fabric-daisies-daisy-fabric-baby-fabric-spring-fabric-baby-girl-earthy-tan-by-charlottewinter', 'path': '/en/fabric/9544489-daisy-print-fabric-daisies-daisy-fabric-baby-fabric-spring-fabric-baby-girl-earthy-tan-by-charlottewinter', 'scraped': 0}, {'id': '6444170', 'slug': 'catching-fireflies-by-thestorysmith', 'path': '/en/fabric/6444170-catching-fireflies-by-thestorysmith', 'scraped': 0}, {'id': '13157281', 'slug': 'nostalgic-vintage-tile-by-garabateo', 'path': '/en/fabric/13157281-nostalgic-vintage-tile-by-garabateo', 'scraped': 0}, {'id': '11125049', 'slug': 'custom-colorway-groovy-mushroom-garden-rusty-orange-by-yesterdaycollection', 'path': '/en/fabric/11125049-custom-colorway-groovy-mushroom-garden-rusty-orange-by-yesterdaycollection', 'scraped': 0}, {'id': '8197261', 'slug': 'night-sky-stars-midnight-blue-space-nig ...
# total time is 15.535914897918701
